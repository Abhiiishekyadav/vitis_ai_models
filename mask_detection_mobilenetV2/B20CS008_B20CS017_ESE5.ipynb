# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages (from opencv-python) (1.21.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importing Libraries

# %%
pip install imutils
# Out:
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25836 sha256=e33278702085c1dc20de42f3bbea0d73dad5c7b11eecd9fafec45e56b1b8224f
#   Stored in directory: /home/vitis-ai-user/.cache/pip/wheels/86/d7/0a/4923351ed1cec5d5e24c1eaf8905567b02a0343b24aa873df2
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import argparse
import os
# Out:
# 2023-06-23 05:34:56.356818: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu
# 2023-06-23 05:34:56.356854: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Importing dataset

# %%
data_path="Covid-19-PIS.v2i.multiclass-20230616T092836Z-001/Covid-19-PIS.v2i.multiclass/train"
csv_path="classes.csv"
label_data=pd.read_csv(csv_path)

# %%
# grab the list of images in our dataset directory, then initialize
# the list of data (i.e., images) and class images
print("[INFO] loading images...")
# imagePaths = list(paths.list_images(args["dataset"]))
imagePaths=list(paths.list_images(data_path))
data = []
labels = []
file_names=list(label_data["filename"].values)
for imagePath in imagePaths:
	index1=file_names.index(imagePath.split("/")[-1]) 
	if(label_data[" with_mask"][index1]==1):
		label="with_mask"
	else:
		label="without_mask"
	# load the input image (224x224) and preprocess it
	image = load_img(imagePath, target_size=(224, 224))
	image = img_to_array(image)
	image = preprocess_input(image)

	# update the data and labels lists, respectively
	data.append(image)
	labels.append(label)

# convert the data and labels to NumPy arrays
data = np.array(data, dtype="float32")
labels = np.array(labels)
# Out:
# [INFO] loading images...

# %%
print(labels)
# Out:
# ['with_mask' 'without_mask' 'without_mask' 'with_mask' 'with_mask'
#  'with_mask' 'without_mask' 'with_mask' 'with_mask' 'without_mask'
#  'with_mask' 'without_mask' 'with_mask' 'without_mask' 'with_mask'
#  'with_mask' 'without_mask' 'without_mask' 'without_mask' 'with_mask'
#  'without_mask' 'with_mask' 'without_mask' 'without_mask' 'with_mask'
#  'without_mask' 'without_mask' 'with_mask' 'without_mask' 'without_mask'
#  'without_mask' 'without_mask' 'without_mask' 'without_mask'
#  'without_mask' 'without_mask' 'with_mask' 'without_mask' 'without_mask'
#  'without_mask' 'without_mask' 'with_mask' 'with_mask' 'with_mask'
#  'with_mask' 'with_mask' 'with_mask' 'with_mask' 'without_mask'
#  'without_mask' 'without_mask' 'with_mask' 'with_mask' 'with_mask'
#  'with_mask' 'with_mask' 'with_mask' 'without_mask' 'without_mask'
#  'without_mask' 'without_mask' 'with_mask' 'without_mask' 'without_mask'
#  'with_mask' 'with_mask' 'with_mask' 'with_mask' 'with_mask' 'with_mask'
#  'without_mask' 'without_mask' 'with_mask' 'with_mask' 'with_mask'
#  'without_mask' 'without_mask' 'without_mask' 'with_mask' 'with_mask'
#  'without_mask' 'with_mask' 'with_mask' 'without_mask' 'without_mask'
#  'with_mask' 'with_mask' 'without_mask' 'with_mask' 'with_mask'
#  'with_mask' 'with_mask' 'without_mask' 'with_mask' 'without_mask'
#  'without_mask' 'without_mask' 'without_mask' 'without_mask'
#  'without_mask' 'with_mask' 'without_mask' 'without_mask' 'with_mask'
#  'with_mask' 'with_mask' 'with_mask' 'without_mask' 'with_mask'
#  'with_mask' 'with_mask' 'without_mask' 'with_mask' 'without_mask'
#  'with_mask' 'without_mask' 'with_mask' 'with_mask' 'with_mask'
#  'without_mask' 'with_mask' 'without_mask' 'with_mask' 'without_mask'
#  'without_mask' 'with_mask' 'with_mask' 'with_mask' 'with_mask'
#  'with_mask' 'without_mask' 'without_mask' 'with_mask' 'with_mask'
#  'with_mask' 'with_mask' 'with_mask' 'without_mask' 'without_mask'
#  'without_mask' 'without_mask' 'without_mask' 'without_mask'
#  'without_mask' 'with_mask' 'with_mask' 'without_mask' 'with_mask'
#  'without_mask' 'without_mask' 'without_mask' 'with_mask' 'without_mask'
#  'without_mask' 'without_mask' 'with_mask' 'with_mask' 'with_mask'
#  'without_mask' 'without_mask' 'without_mask' 'without_mask' 'with_mask'
#  'without_mask' 'without_mask' 'without_mask' 'without_mask'
#  'without_mask' 'without_mask' 'with_mask' 'without_mask']

# %% [markdown]
# ### Splitting the dataset into training and testing

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

# construct the training image generator for data augmentation
aug = ImageDataGenerator(
	rotation_range=20,
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=True,
	fill_mode="nearest")

# %% [markdown]
# ### Defining model parameters

# %%
# initialize the initial learning rate, number of epochs to train for,
# and batch size
INIT_LR = 1e-4
EPOCHS = 10
BS = 32

# %% [markdown]
# ## Designing the model architecture

# %%
# load the MobileNetV2 network, ensuring the head FC layer sets are
# left off
baseModel = MobileNetV2(weights="imagenet", include_top=False,
	input_tensor=Input(shape=(224, 224, 3)))

# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# place the head FC model on top of the base model (this will become
# the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)

# loop over all layers in the base model and freeze them so they will
# *not* be updated during the first training process
for layer in baseModel.layers:
	layer.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# 2023-06-23 05:35:09.064034: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/vitis_ai/conda/envs/vitis-ai-tensorflow2/lib/python3.7/site-packages/cv2/../../lib64:/opt/xilinx/xrt/lib:/usr/lib:/usr/lib/x86_64-linux-gnu
# 2023-06-23 05:35:09.064072: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-06-23 05:35:09.064098: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2023-06-23 05:35:09.064455: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### Compile the model with compile() method and train the model with fit() method

# %%
# compile our model
print("[INFO] compiling model...")
opt = Adam(learning_rate=INIT_LR)
model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])

# train the head of the network
print("[INFO] training head...")
H = model.fit(
	aug.flow(trainX, trainY, batch_size=BS),
	steps_per_epoch=len(trainX) // BS,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BS,
	epochs=EPOCHS)
# Out:
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/10
# 4/4 [==============================] - 5s 576ms/step - loss: 0.6492 - accuracy: 0.6538 - val_loss: 0.6233 - val_accuracy: 0.8000
# Epoch 2/10
# 4/4 [==============================] - 2s 423ms/step - loss: 0.6560 - accuracy: 0.6827 - val_loss: 0.5666 - val_accuracy: 0.9143
# Epoch 3/10
# 4/4 [==============================] - 2s 527ms/step - loss: 0.5571 - accuracy: 0.7981 - val_loss: 0.5193 - val_accuracy: 0.9429
# Epoch 4/10
# 4/4 [==============================] - 2s 417ms/step - loss: 0.5008 - accuracy: 0.8846 - val_loss: 0.4733 - val_accuracy: 0.9714
# Epoch 5/10
# 4/4 [==============================] - 2s 474ms/step - loss: 0.4747 - accuracy: 0.8672 - val_loss: 0.4310 - val_accuracy: 0.9714
# Epoch 6/10
# 4/4 [==============================] - 2s 516ms/step - loss: 0.4132 - accuracy: 0.9327 - val_loss: 0.3896 - val_accuracy: 0.9714
# Epoch 7/10
# 4/4 [==============================] - 2s 482ms/step - loss: 0.3928 - accuracy: 0.9453 - val_loss: 0.3519 - val_accuracy: 0.9714
# Epoch 8/10
# 4/4 [==============================] - 2s 402ms/step - loss: 0.3405 - accuracy: 0.9808 - val_loss: 0.3151 - val_accuracy: 0.9714
# Epoch 9/10
# 4/4 [==============================] - 2s 543ms/step - loss: 0.3436 - accuracy: 0.9327 - val_loss: 0.2816 - val_accuracy: 1.0000
# Epoch 10/10
# 4/4 [==============================] - 2s 526ms/step - loss: 0.2811 - accuracy: 0.9423 - val_loss: 0.2520 - val_accuracy: 1.0000

# %% [markdown]
# #### Making prediction and getting classification report

# %%
# make predictions on the testing set
print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)

# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)

# show a nicely formatted classification report
print(classification_report(testY.argmax(axis=1), predIdxs,target_names=lb.classes_))

# serialize the model to disk
print("[INFO] saving mask detector model...")
# model.save(args["model"], save_format="h5")
model.save("mobilenet_model",save_format="h5")
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#    with_mask       1.00      1.00      1.00        17
# without_mask       1.00      1.00      1.00        18
#
#     accuracy                           1.00        35
#    macro avg       1.00      1.00      1.00        35
# weighted avg       1.00      1.00      1.00        35
#
# [INFO] saving mask detector model...

# %% [markdown]
# #### Plot the training loss and accuracy

# %%
# plot the training loss and accuracy
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
# plt.savefig(args["plot"])

# %%
_,acc=model.evaluate(testX,testY)
print(acc)
# Out:
# 2/2 [==============================] - 1s 37ms/step - loss: 0.2520 - accuracy: 1.0000
# 1.0

# %% [markdown]
# ## Reducing the size of the neural network design

# %% [markdown]
# Effect on accuracy when number of epochs are changed

# %%
acc1=[]
epoch=[]
for i in range(10,16):
  opt = Adam(learning_rate=INIT_LR)
  model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
  H = model.fit(aug.flow(trainX, trainY, batch_size=BS),steps_per_epoch=len(trainX) // BS,validation_data=(testX, testY),validation_steps=len(testX) // BS,epochs=i)
  _,acc=model.evaluate(testX,testY)
  acc1.append(acc*100)
  epoch.append(i)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 6s 744ms/step - loss: 0.2707 - accuracy: 0.9609 - val_loss: 0.2154 - val_accuracy: 0.9714
# Epoch 2/10
# 4/4 [==============================] - 2s 406ms/step - loss: 0.2330 - accuracy: 0.9615 - val_loss: 0.1845 - val_accuracy: 1.0000
# Epoch 3/10
# 4/4 [==============================] - 2s 528ms/step - loss: 0.1846 - accuracy: 0.9808 - val_loss: 0.1619 - val_accuracy: 1.0000
# Epoch 4/10
# 4/4 [==============================] - 2s 415ms/step - loss: 0.2072 - accuracy: 0.9615 - val_loss: 0.1407 - val_accuracy: 1.0000
# Epoch 5/10
# 4/4 [==============================] - 2s 410ms/step - loss: 0.1971 - accuracy: 0.9615 - val_loss: 0.1253 - val_accuracy: 1.0000
# Epoch 6/10
# 4/4 [==============================] - 2s 415ms/step - loss: 0.1364 - accuracy: 0.9904 - val_loss: 0.1148 - val_accuracy: 1.0000
# Epoch 7/10
# 4/4 [==============================] - 2s 513ms/step - loss: 0.1198 - accuracy: 0.9808 - val_loss: 0.1033 - val_accuracy: 1.0000
# Epoch 8/10
# 4/4 [==============================] - 2s 421ms/step - loss: 0.1104 - accuracy: 0.9904 - val_loss: 0.0903 - val_accuracy: 1.0000
# Epoch 9/10
# 4/4 [==============================] - 2s 484ms/step - loss: 0.1082 - accuracy: 0.9844 - val_loss: 0.0801 - val_accuracy: 1.0000
# Epoch 10/10
# 4/4 [==============================] - 2s 424ms/step - loss: 0.0872 - accuracy: 0.9904 - val_loss: 0.0775 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 36ms/step - loss: 0.0775 - accuracy: 1.0000
# Epoch 1/11
# 4/4 [==============================] - 6s 704ms/step - loss: 0.0897 - accuracy: 1.0000 - val_loss: 0.0585 - val_accuracy: 1.0000
# Epoch 2/11
# 4/4 [==============================] - 2s 407ms/step - loss: 0.1007 - accuracy: 0.9808 - val_loss: 0.0573 - val_accuracy: 1.0000
# Epoch 3/11
# 4/4 [==============================] - 2s 477ms/step - loss: 0.0609 - accuracy: 0.9922 - val_loss: 0.0677 - val_accuracy: 1.0000
# Epoch 4/11
# 4/4 [==============================] - 2s 372ms/step - loss: 0.0810 - accuracy: 0.9712 - val_loss: 0.0686 - val_accuracy: 1.0000
# Epoch 5/11
# 4/4 [==============================] - 2s 392ms/step - loss: 0.0615 - accuracy: 0.9904 - val_loss: 0.0567 - val_accuracy: 1.0000
# Epoch 6/11
# 4/4 [==============================] - 2s 376ms/step - loss: 0.0441 - accuracy: 0.9904 - val_loss: 0.0448 - val_accuracy: 1.0000
# Epoch 7/11
# 4/4 [==============================] - 2s 543ms/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 1.0000
# Epoch 8/11
# 4/4 [==============================] - 2s 393ms/step - loss: 0.0367 - accuracy: 0.9808 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 9/11
# 4/4 [==============================] - 2s 405ms/step - loss: 0.0390 - accuracy: 0.9904 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 10/11
# 4/4 [==============================] - 2s 394ms/step - loss: 0.0462 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 11/11
# 4/4 [==============================] - 2s 362ms/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 32ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 1/12
# 4/4 [==============================] - 6s 754ms/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 2/12
# 4/4 [==============================] - 2s 395ms/step - loss: 0.0515 - accuracy: 0.9808 - val_loss: 0.0214 - val_accuracy: 1.0000
# Epoch 3/12
# 4/4 [==============================] - 2s 414ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 1.0000
# Epoch 4/12
# 4/4 [==============================] - 2s 409ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 1.0000
# Epoch 5/12
# 4/4 [==============================] - 2s 364ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 6/12
# 4/4 [==============================] - 2s 404ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 7/12
# 4/4 [==============================] - 2s 367ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 8/12
# 4/4 [==============================] - 2s 408ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 9/12
# 4/4 [==============================] - 2s 362ms/step - loss: 0.0226 - accuracy: 0.9904 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 10/12
# 4/4 [==============================] - 2s 526ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 11/12
# 4/4 [==============================] - 2s 372ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 12/12
# 4/4 [==============================] - 2s 517ms/step - loss: 0.0177 - accuracy: 0.9904 - val_loss: 0.0093 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 35ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 1/13
# 4/4 [==============================] - 6s 691ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 2/13
# 4/4 [==============================] - 2s 353ms/step - loss: 0.0360 - accuracy: 0.9904 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 3/13
# 4/4 [==============================] - 2s 397ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 4/13
# 4/4 [==============================] - 2s 519ms/step - loss: 0.0349 - accuracy: 0.9904 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 5/13
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 6/13
# 4/4 [==============================] - 2s 370ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 7/13
# 4/4 [==============================] - 2s 485ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 8/13
# 4/4 [==============================] - 2s 490ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 9/13
# 4/4 [==============================] - 2s 355ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 10/13
# 4/4 [==============================] - 2s 416ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 11/13
# 4/4 [==============================] - 2s 417ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 12/13
# 4/4 [==============================] - 2s 450ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 13/13
# 4/4 [==============================] - 2s 461ms/step - loss: 0.0103 - accuracy: 0.9922 - val_loss: 0.0040 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 45ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 1/14
# 4/4 [==============================] - 5s 705ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 2/14
# 4/4 [==============================] - 2s 476ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 3/14
# 4/4 [==============================] - 2s 475ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 4/14
# 4/4 [==============================] - 2s 411ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 5/14
# 4/4 [==============================] - 2s 408ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 6/14
# 4/4 [==============================] - 2s 397ms/step - loss: 0.0220 - accuracy: 0.9904 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 7/14
# 4/4 [==============================] - 2s 510ms/step - loss: 7.3872e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 8/14
# 4/4 [==============================] - 2s 413ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 9/14
# 4/4 [==============================] - 2s 406ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 10/14
# 4/4 [==============================] - 2s 413ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 11/14
# 4/4 [==============================] - 2s 398ms/step - loss: 0.0208 - accuracy: 0.9904 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 12/14
# 4/4 [==============================] - 2s 402ms/step - loss: 0.0165 - accuracy: 0.9904 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 13/14
# 4/4 [==============================] - 2s 367ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 14/14
# 4/4 [==============================] - 2s 388ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 37ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 1/15
# 4/4 [==============================] - 6s 708ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 2/15
# 4/4 [==============================] - 2s 507ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 3/15
# 4/4 [==============================] - 2s 480ms/step - loss: 9.7060e-04 - accuracy: 1.0000 - val_loss: 8.0060e-04 - val_accuracy: 1.0000
# Epoch 4/15
# 4/4 [==============================] - 2s 417ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 9.5095e-04 - val_accuracy: 1.0000
# Epoch 5/15
# 4/4 [==============================] - 2s 520ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 6/15
# 4/4 [==============================] - 2s 387ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 7/15
# 4/4 [==============================] - 2s 397ms/step - loss: 0.0166 - accuracy: 0.9904 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 8/15
# 4/4 [==============================] - 2s 402ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 9/15
# 4/4 [==============================] - 2s 404ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 10/15
# 4/4 [==============================] - 2s 395ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 11/15
# 4/4 [==============================] - 2s 472ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 12/15
# 4/4 [==============================] - 2s 501ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 13/15
# 4/4 [==============================] - 2s 505ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 14/15
# 4/4 [==============================] - 2s 480ms/step - loss: 6.7997e-04 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 15/15
# 4/4 [==============================] - 2s 368ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 35ms/step - loss: 0.0054 - accuracy: 1.0000

# %%
plt.plot(epoch, acc1 )
plt.xlabel('Number of epoch')
plt.ylabel('Accuracy')
plt.title('Effect on accuracy when number of epochs are changed')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Model robustness check

# %%
original_w = model.get_weights()

# %%
weights=original_w

# %%
num_layers=4

# %% [markdown]
# Defining scalars and changing weights of every layer by multipyling those scalars one by one

# %%
accuracys=[]
x=num_layers-1
for i in range(len(original_w)-2,len(original_w)-1-(2*x),-2):
  accuracy=[]
  print("Layer :",x)
  for scalar in [.25, 0.4, 0.6, 0.85, 0.96,1, 1.1,1.25,1.5,1.75,2.]:
    new_w=[]
    for w in range(len(original_w)):
      if(w==i):
        new_w.append(original_w[w]*scalar)
      else:
        new_w.append(original_w[w])
    model.set_weights(new_w)
    evaluation = model.evaluate(testX, testY)
    print("Scalar {} --> test accuracy {}".format(scalar,evaluation[1]))
    accuracy.append(evaluation[1])
    model.set_weights(original_w)
  x-=1
  model.set_weights(original_w)
  accuracys.append(accuracy)
# Out:
# Layer : 3
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0930 - accuracy: 1.0000
# Scalar 0.25 --> test accuracy 1.0
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0351 - accuracy: 1.0000
# Scalar 0.4 --> test accuracy 1.0
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0149 - accuracy: 1.0000
# Scalar 0.6 --> test accuracy 1.0
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0075 - accuracy: 1.0000
# Scalar 0.85 --> test accuracy 1.0
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0059 - accuracy: 1.0000
# Scalar 0.96 --> test accuracy 1.0
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0054 - accuracy: 1.0000
# Scalar 1 --> test accuracy 1.0
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0044 - accuracy: 1.0000
# Scalar 1.1 --> test accuracy 1.0
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0033 - accuracy: 1.0000
# Scalar 1.25 --> test accuracy 1.0
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0021 - accuracy: 1.0000
# Scalar 1.5 --> test accuracy 1.0
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0013 - accuracy: 1.0000
# Scalar 1.75 --> test accuracy 1.0
# 2/2 [==============================] - 0s 38ms/step - loss: 8.6328e-04 - accuracy: 1.0000
# Scalar 2.0 --> test accuracy 1.0
# Layer : 2
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0924 - accuracy: 1.0000
# Scalar 0.25 --> test accuracy 1.0
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0350 - accuracy: 1.0000
# Scalar 0.4 --> test accuracy 1.0
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0149 - accuracy: 1.0000
# Scalar 0.6 --> test accuracy 1.0
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0075 - accuracy: 1.0000
# Scalar 0.85 --> test accuracy 1.0
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0059 - accuracy: 1.0000
# Scalar 0.96 --> test accuracy 1.0
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0054 - accuracy: 1.0000
# Scalar 1 --> test accuracy 1.0
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0044 - accuracy: 1.0000
# Scalar 1.1 --> test accuracy 1.0
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0033 - accuracy: 1.0000
# Scalar 1.25 --> test accuracy 1.0
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0021 - accuracy: 1.0000
# Scalar 1.5 --> test accuracy 1.0
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0013 - accuracy: 1.0000
# Scalar 1.75 --> test accuracy 1.0
# 2/2 [==============================] - 0s 41ms/step - loss: 8.5991e-04 - accuracy: 1.0000
# Scalar 2.0 --> test accuracy 1.0
# Layer : 1
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0918 - accuracy: 1.0000
# Scalar 0.25 --> test accuracy 1.0
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0349 - accuracy: 1.0000
# Scalar 0.4 --> test accuracy 1.0
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0149 - accuracy: 1.0000
# Scalar 0.6 --> test accuracy 1.0
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0075 - accuracy: 1.0000
# Scalar 0.85 --> test accuracy 1.0
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0059 - accuracy: 1.0000
# Scalar 0.96 --> test accuracy 1.0
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0054 - accuracy: 1.0000
# Scalar 1 --> test accuracy 1.0
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0044 - accuracy: 1.0000
# Scalar 1.1 --> test accuracy 1.0
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0033 - accuracy: 1.0000
# Scalar 1.25 --> test accuracy 1.0
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0021 - accuracy: 1.0000
# Scalar 1.5 --> test accuracy 1.0
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0013 - accuracy: 1.0000
# Scalar 1.75 --> test accuracy 1.0
# 2/2 [==============================] - 0s 38ms/step - loss: 8.6087e-04 - accuracy: 1.0000
# Scalar 2.0 --> test accuracy 1.0

# %% [markdown]
# Plotting graph for each layer for each scalar multiplied vs accuracy

# %%
scalars=[.25, 0.4, 0.6, 0.85, 0.96, 1, 1.1,1.25,1.5,1.75,2.]
for i in range(len(accuracys)):
  plt.plot(scalars, accuracys[i], label=f'layer {num_layers-i-1}')
plt.xlabel('Scalar')
plt.ylabel('Accuracy')
plt.title('Effect on accuracy when weights are multiplied by scalers')
plt.legend()
plt.show()

# %% [markdown]
# Defining scalars and changing weights of every layer by adding those scalars one by one

# %%
accuracys=[]
x=num_layers-1
for i in range(len(original_w)-2,len(original_w)-1-(2*x),-2):
  accuracy=[]
  print("Layer :",x)
  for scalar in [.25, 0.4, 0.6, 0.85, 0.96,1, 1.1,1.25,1.5,1.75,2.]:
    new_w=[]
    for w in range(len(original_w)):
      if(w==i):
        new_w.append(original_w[w]+scalar)
      else:
        new_w.append(original_w[w])
    model.set_weights(new_w)
    evaluation = model.evaluate(testX, testY)
    print("Scalar {} --> test accuracy {}".format(scalar,evaluation[1]))
    accuracy.append(evaluation[1])
    model.set_weights(original_w)
  x-=1
  model.set_weights(original_w)
  accuracys.append(accuracy)
# Out:
# Layer : 3
# 2/2 [==============================] - 0s 43ms/step - loss: 8.7236 - accuracy: 1.0000
# Scalar 0.25 --> test accuracy 1.0
# 2/2 [==============================] - 0s 36ms/step - loss: 16.9669 - accuracy: 1.0000
# Scalar 0.4 --> test accuracy 1.0
# 2/2 [==============================] - 0s 54ms/step - loss: 27.9581 - accuracy: 1.0000
# Scalar 0.6 --> test accuracy 1.0
# 2/2 [==============================] - 0s 43ms/step - loss: 41.6970 - accuracy: 1.0000
# Scalar 0.85 --> test accuracy 1.0
# 2/2 [==============================] - 0s 31ms/step - loss: 47.7421 - accuracy: 1.0000
# Scalar 0.96 --> test accuracy 1.0
# 2/2 [==============================] - 0s 35ms/step - loss: 49.9403 - accuracy: 1.0000
# Scalar 1 --> test accuracy 1.0
# 2/2 [==============================] - 0s 37ms/step - loss: 55.4359 - accuracy: 1.0000
# Scalar 1.1 --> test accuracy 1.0
# 2/2 [==============================] - 0s 35ms/step - loss: 63.6792 - accuracy: 1.0000
# Scalar 1.25 --> test accuracy 1.0
# 2/2 [==============================] - 0s 43ms/step - loss: 77.4181 - accuracy: 1.0000
# Scalar 1.5 --> test accuracy 1.0
# 2/2 [==============================] - 0s 32ms/step - loss: 91.1570 - accuracy: 1.0000
# Scalar 1.75 --> test accuracy 1.0
# 2/2 [==============================] - 0s 40ms/step - loss: 104.8959 - accuracy: 1.0000
# Scalar 2.0 --> test accuracy 1.0
# Layer : 2
# 2/2 [==============================] - 0s 35ms/step - loss: 6.3980 - accuracy: 0.5143
# Scalar 0.25 --> test accuracy 0.5142857432365417
# 2/2 [==============================] - 0s 33ms/step - loss: 13.9922 - accuracy: 0.5143
# Scalar 0.4 --> test accuracy 0.5142857432365417
# 2/2 [==============================] - 0s 40ms/step - loss: 24.1347 - accuracy: 0.5143
# Scalar 0.6 --> test accuracy 0.5142857432365417
# 2/2 [==============================] - 0s 43ms/step - loss: 36.8127 - accuracy: 0.5143
# Scalar 0.85 --> test accuracy 0.5142857432365417
# 2/2 [==============================] - 0s 35ms/step - loss: 42.3911 - accuracy: 0.5143
# Scalar 0.96 --> test accuracy 0.5142857432365417
# 2/2 [==============================] - 0s 40ms/step - loss: 44.4196 - accuracy: 0.5143
# Scalar 1 --> test accuracy 0.5142857432365417
# 2/2 [==============================] - 0s 40ms/step - loss: 49.4908 - accuracy: 0.5143
# Scalar 1.1 --> test accuracy 0.5142857432365417
# 2/2 [==============================] - 0s 34ms/step - loss: 57.0976 - accuracy: 0.5143
# Scalar 1.25 --> test accuracy 0.5142857432365417
# 2/2 [==============================] - 0s 31ms/step - loss: 69.7757 - accuracy: 0.5143
# Scalar 1.5 --> test accuracy 0.5142857432365417
# 2/2 [==============================] - 0s 38ms/step - loss: 82.4537 - accuracy: 0.5143
# Scalar 1.75 --> test accuracy 0.5142857432365417
# 2/2 [==============================] - 0s 40ms/step - loss: 95.1317 - accuracy: 0.5143
# Scalar 2.0 --> test accuracy 0.5142857432365417
# Layer : 1
# 2/2 [==============================] - 0s 31ms/step - loss: 2.5634 - accuracy: 0.6000
# Scalar 0.25 --> test accuracy 0.6000000238418579
# 2/2 [==============================] - 0s 30ms/step - loss: 5.9633 - accuracy: 0.4857
# Scalar 0.4 --> test accuracy 0.48571428656578064
# 2/2 [==============================] - 0s 35ms/step - loss: 10.8758 - accuracy: 0.4857
# Scalar 0.6 --> test accuracy 0.48571428656578064
# 2/2 [==============================] - 0s 35ms/step - loss: 17.5097 - accuracy: 0.4857
# Scalar 0.85 --> test accuracy 0.48571428656578064
# 2/2 [==============================] - 0s 36ms/step - loss: 20.4741 - accuracy: 0.4857
# Scalar 0.96 --> test accuracy 0.48571428656578064
# 2/2 [==============================] - 0s 38ms/step - loss: 21.5527 - accuracy: 0.4857
# Scalar 1 --> test accuracy 0.48571428656578064
# 2/2 [==============================] - 0s 32ms/step - loss: 24.2498 - accuracy: 0.4857
# Scalar 1.1 --> test accuracy 0.48571428656578064
# 2/2 [==============================] - 0s 35ms/step - loss: 28.2958 - accuracy: 0.4857
# Scalar 1.25 --> test accuracy 0.48571428656578064
# 2/2 [==============================] - 0s 36ms/step - loss: 35.0392 - accuracy: 0.4857
# Scalar 1.5 --> test accuracy 0.48571428656578064
# 2/2 [==============================] - 0s 44ms/step - loss: 41.7826 - accuracy: 0.4857
# Scalar 1.75 --> test accuracy 0.48571428656578064
# 2/2 [==============================] - 0s 41ms/step - loss: 48.5260 - accuracy: 0.4857
# Scalar 2.0 --> test accuracy 0.48571428656578064

# %% [markdown]
#  Plotting graph for each layer for each scalar added vs accuracy

# %%
scalars=[.25, 0.4, 0.6, 0.85, 0.96, 1, 1.1,1.25,1.5,1.75,2.]
for i in range(len(accuracys)):
  plt.plot(scalars, accuracys[i], label=f'layer {num_layers-i-1}')
plt.xlabel('Scalar')
plt.ylabel('Accuracy')
plt.title('Effect on accuracy when weights are added by scalers')
plt.legend()
plt.show()

# %% [markdown]
# Prediction on Image

# %%
# import the necessary packages
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
import numpy as np
import argparse
import cv2
import os

# %% [markdown]
# #### Downloading opencv pakages

# %%
# import urllib.request

# # Downloading deploy.prototxt file
# urllib.request.urlretrieve('https://github.com/opencv/opencv/raw/master/samples/dnn/face_detector/deploy.prototxt',
#                            '/content/deploy.prototxt')

# # Downloading res10_300x300_ssd_iter_140000.caffemodel file
# urllib.request.urlretrieve('https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel',
#                            '/content/res10_300x300_ssd_iter_140000.caffemodel')

# %% [markdown]
# Loading model and face detector files

# %%
import urllib.request

# Downloading deploy.prototxt file
urllib.request.urlretrieve('https://github.com/opencv/opencv/raw/master/samples/dnn/face_detector/deploy.prototxt',
                           'deploy.prototxt')
# Out:
# ('deploy.prototxt', <http.client.HTTPMessage at 0x7f499410dbd0>)

# %%
# Downloading res10_300x300_ssd_iter_140000.caffemodel file
urllib.request.urlretrieve('https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel',
                           'res10_300x300_ssd_iter_140000.caffemodel')
# Out:
# ('res10_300x300_ssd_iter_140000.caffemodel',
#  <http.client.HTTPMessage at 0x7f499c60c8d0>)

# %%
# load our serialized face detector model from disk
print("[INFO] loading face detector model...")
prototxtPath = "deploy.prototxt"
weightsPath="res10_300x300_ssd_iter_140000.caffemodel"
net = cv2.dnn.readNetFromCaffe(prototxtPath, weightsPath)

# load the face mask detector model from disk
print("[INFO] loading face mask detector model...")
model=load_model("mobilenet_model")
# Out:
# [INFO] loading face detector model...
# [INFO] loading face mask detector model...

# %% [markdown]
# #### Detection function for image input

# %%
def detection_path(image_path):
  testing_image=image_path
  # image = cv2.imread(args["image"])
  image=cv2.imread(testing_image)
  orig = image.copy()
  (h, w) = image.shape[:2]
  # print(image.shape)

  re_image = cv2.resize(image, (300, 300)) # resize the image to (300, 300)
  blob = cv2.dnn.blobFromImage(re_image, 1.0, (300, 300),(104.0, 177.0, 123.0))
  # pass the blob through the network and obtain the face detections
  print("[INFO] computing face detections...")
  net.setInput(blob)
  detections = net.forward()
  # loop over the detections
  for i in range(0, detections.shape[2]):
    # extract the confidence (i.e., probability) associated with
    # the detection
    confidence = detections[0, 0, i, 2]

    # filter out weak detections by ensuring the confidence is
    # greater than the minimum confidence
    if confidence > 0.95:
      # compute the (x, y)-coordinates of the bounding box for
      # the object
      box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
      (startX, startY, endX, endY) = box.astype("int")

      # ensure the bounding boxes fall within the dimensions of
      # the frame
      (startX, startY) = (max(0, startX), max(0, startY))
      (endX, endY) = (min(w - 1, endX), min(h - 1, endY))
  # extract the face ROI, convert it from BGR to RGB channel
      # ordering, resize it to 224x224, and preprocess it
  face = image[startY:endY, startX:endX]
  face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
  face = cv2.resize(face, (224, 224))
  face = img_to_array(face)
  face = preprocess_input(face)
  face = np.expand_dims(face, axis=0)

      # pass the face through the model to determine if the face
      # has a mask or not
  (mask, withoutMask) = model.predict(face)[0]
      # determine the class label and color we'll use to draw
      # the bounding box and text
#   from google.colab.patches import cv2_imshow
  import matplotlib.pyplot as plt
  label = "Mask" if mask > withoutMask else "No Mask"
  print("Category:",label)
  color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

      # include the probability in the label
  label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)

      # display the label and bounding box rectangle on the output
      # frame
  cv2.putText(image, label, (startX, startY - 10),
  cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
  cv2.rectangle(image, (startX, startY), (endX, endY), color, 2)

  # show the output image
  plt.imshow(image)
  cv2.waitKey(0)

# %%
import cv2

# %%
image_path='Untitled.jpg'   # give the image path...
detection_path(image_path)
# Out:
# [INFO] computing face detections...
# Category: Mask

# %% [markdown]
# ### Input By Webcam

# %% [markdown]
# Enable Environment

# %%
# !pip install virtualenv
# !virtualenv myenv
# !source myenv/bin/activate
# !pip install jupyter-webrtc

# %% [markdown]
# Input from Webcam

# %%
# from google.colab import drive
# from google.colab import files
from IPython.display import display, Javascript
from PIL import Image
import io

# Install jupyter-webrtc
# !pip install jupyter-webrtc

# Grant permission to the camera
def enable_camera():
  from google.colab.output import eval_js
  from base64 import b64decode
  from IPython.display import display
  from PIL import Image
  import io

  def takePhoto(filename='photo.jpg', quality=1.0):
    js = Javascript('''
      async function takePhoto(quality) {
        const div = document.createElement('div');
        const video = document.createElement('video');
        const button = document.createElement('button');
        video.style.display = 'block';
        button.style.display = 'block';
        button.textContent = 'Capture';
        const stream = await navigator.mediaDevices.getUserMedia({video: true});
        document.body.appendChild(div);
        div.appendChild(video);
        div.appendChild(button);
        video.srcObject = stream;
        await video.play();
        // Resize the output to fit the video element.
        google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true, {maxHeight: 5000});
        await new Promise((resolve) => button.onclick = resolve);
        const canvas = document.createElement('canvas');
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        canvas.getContext('2d').drawImage(video, 0, 0);
        stream.getVideoTracks()[0].stop();
        div.remove();
        return canvas.toDataURL('image/jpeg', quality);
      }
      ''')
    display(js)
    data = eval_js('takePhoto({})'.format(quality))
    binary = b64decode(data.split(',')[1])
    f = io.BytesIO(binary)
    img = Image.open(f)
    print("Image Saved, path='/content/sample.jpg'")
    img.save("/content/sample.jpg",'JPEG')
    return img


  try:
    img = takePhoto()
    print("Camera access granted")
    display(img)
  except Exception as e:
    print("Error accessing camera:", e)

enable_camera()
# Out:
# ERROR: Could not find a version that satisfies the requirement jupyter-webrtc (from versions: none)
# ERROR: No matching distribution found for jupyter-webrtc
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1464866/1848288947.py in <module>
#      61     print("Error accessing camera:", e)
#      62
# ---> 63 enable_camera()
#
# /tmp/ipykernel_1464866/1848288947.py in enable_camera()
#      11 def enable_camera():
#      12 #   from google.colab.output import eval_js
# ---> 13   import eval_js
#      14   from base64 import b64decode
#      15   from IPython.display import display
#
# ModuleNotFoundError: No module named 'eval_js'

# %%
image_path="/content/sample.jpg"
detection_path(image_path)
# Out:
# [INFO] computing face detections...
# 1/1 [==============================] - 0s 35ms/step
# Category: Mask
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FBEE6A7CA00>

# %% [markdown]
# Quantization of model

# %%
import tensorflow as tf

# Load the floating-point model
model = tf.keras.models.load_model('mobilenet_model')

# Convert the model to a quantized model
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]
quantized_model = converter.convert()

# Save the quantized model
with open('quantized_model.tflite', 'wb') as f:
    f.write(quantized_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.

# %%
from tensorflow_model_optimization.quantization.keras import vitis_quantize

# %%
quantizer = vitis_quantize.VitisQuantizer(model)
quantized_model = quantizer.quantize_model(calib_dataset = testX, weight_bit=8, activation_bit=8)

quantized_model.compile(loss='categorical_crossentropy', metrics=["accuracy"])

score = quantized_model.evaluate(testX , testY,verbose=0, batch_size=1)
print(score)
print('last')
quantized_model.save('fmd_cs008.h5')
# Out:
# [VAI INFO] Update activation_bit: 8
# [VAI INFO] Update weight_bit: 8
# [VAI INFO] Start CrossLayerEqualization...
# 10/10 [==============================] - 8s 923ms/step
# [VAI INFO] CrossLayerEqualization Done.
# [VAI INFO] Start Quantize Calibration...
# 2/2 [==============================] - 26s 190ms/step
# [VAI INFO] Quantize Calibration Done.
# [VAI INFO] Start Post-Quant Model Refinement...
# [VAI INFO] Start Quantize Position Ajustment...
# [VAI INFO] Quantize Position Ajustment Done.
# [VAI INFO] Post-Quant Model Refninement Done.
# [VAI INFO] Start Model Finalization...
# [VAI INFO] Model Finalization Done.
# [VAI INFO] Quantization Finished.
# [1.2733572721481323, 0.5142857432365417]
# last
